# %%
import pandas as pd
import torch
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

path = "datasets/"
values = torch.load(path +"values.pt")
datetimes = torch.load(path + "datetimes.pt")
print(values.shape)
# Out:
# torch.Size([320, 1, 26304])

# %%
df = pd.DataFrame(values[:,0,:].numpy(), columns = datetimes)
df.head()
# Out:
#    2016-07-01 02:00:00  2016-07-01 03:00:00  2016-07-01 04:00:00  \
# 0                 14.0                 18.0                 21.0
# 1                 69.0                 92.0                 96.0
# 2                234.0                312.0                312.0
# 3                415.0                556.0                560.0
# 4                215.0                292.0                272.0
#
#    2016-07-01 05:00:00  2016-07-01 06:00:00  2016-07-01 07:00:00  \
# 0                 20.0                 22.0                 20.0
# 1                 92.0                 91.0                 92.0
# 2                312.0                312.0                187.0
# 3                443.0                346.0                340.0
# 4                213.0                190.0                178.0
#
#    2016-07-01 08:00:00  2016-07-01 09:00:00  2016-07-01 10:00:00  \
# 0                 20.0                 20.0                 13.0
# 1                 91.0                 92.0                 91.0
# 2                138.0                  8.0                  7.0
# 3                376.0                361.0                259.0
# 4                199.0                187.0                144.0
#
#    2016-07-01 11:00:00  ...  2019-07-01 16:00:00  2019-07-01 17:00:00  \
# 0                 11.0  ...                  8.0                 17.0
# 1                 96.0  ...                109.0                117.0
# 2                  8.0  ...                  7.0                  7.0
# 3                402.0  ...                550.0                564.0
# 4                172.0  ...                259.0                245.0
#
#    2019-07-01 18:00:00  2019-07-01 19:00:00  2019-07-01 20:00:00  \
# 0                 13.0                 10.0                 11.0
# 1                118.0                115.0                117.0
# 2                  8.0                 10.0                 12.0
# 3                620.0                669.0                830.0
# 4                267.0                274.0                351.0
#
#    2019-07-01 21:00:00  2019-07-01 22:00:00  2019-07-01 23:00:00  \
# 0                 11.0                 11.0                 12.0
# 1                116.0                103.0                 93.0
# 2                  8.0                  8.0                  8.0
# 3                844.0                749.0                650.0
# 4                384.0                371.0                346.0
#
#    2019-07-02 00:00:00  2019-07-02 01:00:00
# 0                 10.0                 11.0
# 1                 92.0                 88.0
# 2                  8.0                  8.0
# 3                646.0                648.0
# 4                349.0                337.0
#
# [5 rows x 26304 columns]

# %%
plt.scatter(df.mean(axis=1), df.max(axis=1))
plt.xlabel("Mean")
plt.ylabel("Max")
plt.title("Individuals statistitics distributions")
# Out:
# Text(0.5, 1.0, 'Individuals statistitics distributions')

# %%
outliers = df[df.max(axis=1) > 1e5].reset_index(drop=True)
outliers.shape
# Out:
# (2, 26304)

# %%
plt.plot(outliers.iloc[0])

# %%
plt.plot(outliers.iloc[0][datetimes[-8000:-5000]])

# %%
plt.plot(outliers.iloc[0][datetimes[-4900:-4400]])

# %%
plt.plot(outliers.iloc[1])
